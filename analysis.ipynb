# %% [markdown]
# # Data Analysis Notebook
#
# This notebook loads a dataset from the `data/` folder and performs a basic first-pass analysis.

# %%
import pandas as pd
from functions import read_data

# %%
file_name = "sample.csv"
df = read_data(file_name)
df.head()
# Out:
#     name   department  age  salary  years_at_company
# 0  Alice        Sales   29   52000                 2
# 1    Bob  Engineering   35   81000                 6
# 2  Carla    Marketing   31   61000                 4
# 3  David  Engineering   42   95000                10
# 4  Elena      Finance   27   58000                 3

# %% [markdown]
# ## Basic overview

# %%
print(f"Rows: {df.shape[0]}")
print(f"Columns: {df.shape[1]}")

print("\nColumn names:")
print(df.columns.tolist())

print("\nData types:")
print(df.dtypes)
# Out:
# Rows: 5
# Columns: 5
#
# Column names:
# ['name', 'department', 'age', 'salary', 'years_at_company']
#
# Data types:
# name                  str
# department            str
# age                 int64
# salary              int64
# years_at_company    int64
# dtype: object

# %% [markdown]
# ## Missing values

# %%
df.isna().sum()
# Out:
# name                0
# department          0
# age                 0
# salary              0
# years_at_company    0
# dtype: int64

# %% [markdown]
# ## Summary statistics

# %%
df.describe(include="all").T
# Out:
#                  count unique          top freq     mean           std  \
# name                 5      5        Alice    1      NaN           NaN
# department           5      4  Engineering    2      NaN           NaN
# age                5.0    NaN          NaN  NaN     32.8      5.932959
# salary             5.0    NaN          NaN  NaN  69400.0  17980.545042
# years_at_company   5.0    NaN          NaN  NaN      5.0      3.162278
#
#                       min      25%      50%      75%      max
# name                  NaN      NaN      NaN      NaN      NaN
# department            NaN      NaN      NaN      NaN      NaN
# age                  27.0     29.0     31.0     35.0     42.0
# salary            52000.0  58000.0  61000.0  81000.0  95000.0
# years_at_company      2.0      3.0      4.0      6.0     10.0
